# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib as mpt
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline
from numpy.random import randn
import seaborn as sns

# %%
dt1 = randn(120)

# %%
plt.hist(dt1)
# Out:
# (array([ 2.,  5.,  9., 25., 27., 28., 12.,  6.,  4.,  2.]),
#  array([-2.71096729, -2.14966702, -1.58836674, -1.02706647, -0.46576619,
#          0.09553408,  0.65683435,  1.21813463,  1.7794349 ,  2.34073518,
#          2.90203545]),
#  <a list of 10 Patch objects>)

# %%
dt2 = randn(700)

# %%
plt.hist(dt2,color='indianred')
# Out:
# (array([  8.,  36.,  57., 133., 169., 141.,  97.,  43.,  13.,   3.]),
#  array([-2.66513262, -2.09355994, -1.52198727, -0.9504146 , -0.37884192,
#          0.19273075,  0.76430342,  1.3358761 ,  1.90744877,  2.47902144,
#          3.05059412]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dt1,density=True,alpha=0.5)
plt.hist(dt2,density=True,color='indianred',alpha=0.5)
# Out:
# (array([0.01999496, 0.08997731, 0.14246407, 0.33241617, 0.42239348,
#         0.35241113, 0.24243886, 0.1074729 , 0.03249181, 0.00749811]),
#  array([-2.66513262, -2.09355994, -1.52198727, -0.9504146 , -0.37884192,
#          0.19273075,  0.76430342,  1.3358761 ,  1.90744877,  2.47902144,
#          3.05059412]),
#  <a list of 10 Patch objects>)

# %%
dt3=randn(500)
dt4=randn(500)

# %%
sns.jointplot([dt3],[dt4])

# %%
sns.jointplot([dt3],[dt4],kind='hex')

# %%
x=np.arange(10,100,20)

# %%
x
# Out:
# array([10, 30, 50, 70, 90])
