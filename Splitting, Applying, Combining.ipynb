# %%
import numpy as np
from pandas import Series,DataFrame
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\abelu\\Desktop\\Complete-Python-3-Bootcamp-master (1)'

# %%
df1=pd.read_csv('C:\\Users\\abelu\\Desktop\\Temp\\winequality_red.csv',sep=';')

# %%
df1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar   ...       pH  sulphates  alcohol  quality
# 0            7.4              0.70         0.00             1.9   ...     3.51       0.56      9.4        5
# 1            7.8              0.88         0.00             2.6   ...     3.20       0.68      9.8        5
# 2            7.8              0.76         0.04             2.3   ...     3.26       0.65      9.8        5
# 3           11.2              0.28         0.56             1.9   ...     3.16       0.58      9.8        6
# 4            7.4              0.70         0.00             1.9   ...     3.51       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
def rankit(df):
    df['alco_qual_rank'] = np.arange(len(df))+1
    return df

# %%
df1.sort_values('alcohol',ascending=False,inplace=True)
df1=df1.groupby('quality').apply(rankit)

# %%
df1.head()
# Out:
#       fixed acidity  volatile acidity  citric acid       ...        alcohol  quality  alco_qual_rank
# 652            15.9              0.36         0.65       ...           14.9        5               1
# 588             5.0              0.42         0.24       ...           14.0        8               1
# 142             5.2              0.34         0.00       ...           14.0        6               1
# 144             5.2              0.34         0.00       ...           14.0        6               2
# 1270            5.0              0.38         0.01       ...           14.0        6               3
#
# [5 rows x 13 columns]

# %%
qualnum=df1['quality']
qualnum
# Out:
# (652     5
#  588     8
#  142     6
#  144     6
#  1270    6
#  1269    8
#  467     6
#  821     7
#  1114    6
#  1228    7
#  1132    7
#  1477    7
#  1475    7
#  1126    6
#  492     7
#  484     6
#  455     8
#  378     6
#  491     7
#  1118    6
#  910     6
#  45      4
#  1120    8
#  198     7
#  353     5
#  395     7
#  1287    5
#  132     5
#  131     5
#  982     6
#         ..
#  567     6
#  367     5
#  500     6
#  18      4
#  463     5
#  603     6
#  459     3
#  236     6
#  102     6
#  1533    5
#  99      6
#  593     5
#  89      5
#  239     6
#  496     6
#  238     6
#  167     4
#  235     6
#  234     6
#  601     6
#  1434    6
#  120     5
#  1435    6
#  1474    5
#  1476    5
#  371     6
#  528     6
#  1436    5
#  544     6
#  517     3
#  Name: quality, Length: 1599, dtype: int64,
#  <function sorted(iterable, /, *, key=None, reverse=False)>)

# %%
df1[df1.alco_qual_rank==1].head(len(qualnum))
# Out:
#      fixed acidity  volatile acidity  citric acid       ...        alcohol  quality  alco_qual_rank
# 652           15.9              0.36         0.65       ...           14.9        5               1
# 588            5.0              0.42         0.24       ...           14.0        8               1
#
# [2 rows x 13 columns]

# %%
len(qualnum)
# Out:
# 2

# %%
df1[df1.alco_qual_rank==1]
# Out:
#      fixed acidity  volatile acidity  citric acid       ...        alcohol  quality  alco_qual_rank
# 652           15.9              0.36         0.65       ...           14.9        5               1
# 588            5.0              0.42         0.24       ...           14.0        8               1
# 142            5.2              0.34         0.00       ...           14.0        6               1
# 821            4.9              0.42         0.00       ...           14.0        7               1
# 45             4.6              0.52         0.15       ...           13.1        4               1
# 899            8.3              1.02         0.02       ...           11.0        3               1
#
# [6 rows x 13 columns]

# %%
df1
# Out:
#       fixed acidity  volatile acidity  citric acid       ...          alcohol  quality  alco_qual_rank
# 652            15.9             0.360         0.65       ...        14.900000        5               1
# 588             5.0             0.420         0.24       ...        14.000000        8               1
# 142             5.2             0.340         0.00       ...        14.000000        6               1
# 144             5.2             0.340         0.00       ...        14.000000        6               2
# 1270            5.0             0.380         0.01       ...        14.000000        6               3
# 1269            5.5             0.490         0.03       ...        14.000000        8               2
# 467             8.8             0.460         0.45       ...        14.000000        6               4
# 821             4.9             0.420         0.00       ...        14.000000        7               1
# ...
